# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
test_soup = create_soup("https://www.realtor.com/realestateandhomes-detail/11400-Midbury-Ct_Austin_TX_78748_M78631-75807?view=qv")

# %%
print(test_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://static.rdc-next-basecamp.rdc.moveaws.com/assets/favicon-144287b492113455703667bc3182768a9b2666765a1cd4beba38cfe40294eccc.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="app-id=com.move.realtor" name="google-play-app"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=5, viewport-fit=cover" name="viewport"/>
#   <meta content="Large butlers pantry with space | View 40 photos of this 4 bed, 2+ bath, 2,834 Sq. Ft. single family home at 11400 Midbury Ct, Austin, TX 78748 on sale now for $308,900." name="description">
#    <meta content="authenticity_token" name="csrf-param">
#     <meta content="TIUw05qAbEgTsc1QUn1u0dkok+HK40h0nsDT/4bKv+xSdS3Nk1cJ2fiyvtf2gGekdhvTfXl45ko5kwR0Dkcczw==" name="csrf-token"/>
#     <link data-turbolinks-track="true" href="https://static.rdc-next-basecamp.rdc.moveaws.com/assets/application-85c92cf7e92b290743f2108b316ebf1cf66c3b3b246cfd34900cfbe5d36acdde.css" media="all" rel="stylesheet"/>
#     <link data-turbolinks-track="true" href="https://static.rdc-next-basecamp.rdc.moveaws.com/assets/roboto-font-b0ec718e28a98b0189eda9405f0a5b01b9a8b542f8d89821959d04fa572da952.css" media="all" rel="stylesheet"/>
#     <link href="https://static.rdc-next-basecamp.rdc.moveaws.com/assets/ldp-8895b2817b49634d9f0b0d4bc31751604d611beb028ba87ab0a881e69f2d41ff.css" media="all" rel="stylesheet"/>
#     <title>
#      11400 Midbury Ct, Austin, TX 78748 - realtor.com®
#     </title>
#     <link href="https://static.rdc-next-basecamp.rdc.moveaws.com/assets/apple-touch-icon-050bdb9e192096f6ca07f7c4cc24eaafc1320f74b1b82f3a8a1e92acf84ccb42.png" rel="apple-touch-icon" type="image/png"/>
#     <link href="//ap.rdcpix.com/" rel="preconnect"/>
#     <link href="//dy0wsww1w6so8.cloudfront.net" rel="preconnect"/>
#     <link href="//d33nq717p9jm1d.cloudfront.net" rel="preconnect"/>
#     <link href="https://www.realtor.com/realestateandhomes-detail/11400-Midbury-Ct_Austin_TX_78748_M78631-75807" rel="canonical">
#      <link data-css-url="https://static.rdc-next-basecamp.rdc.moveaws.com/assets/print-421b0d932090903d963a8536b73a382278398995e14a35d127822d3b2dd1e1b1.css" href="" id="print_css" media="print" rel="stylesheet"/>
#      <script>
#       window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"f2a8febd4f","applicationID":"88693780","transactionName":"cFxZEBBWWA5dSh5IFlxDUhYWQGsGXUxQUQhAHEQMDU4=","queueTime":0,"applicationTime":2,"agent":""}
#      </script>
#      <script>
#       (window.NREUM||(NREUM={})).loader_config={xpid:"VwEPVF5XGwsIUlhRAAkH"};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(18),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(19),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var x=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof x&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof x&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(21)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t ...
#      </script>
#      <script defer="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#      </script>
#      <script type="text/javascript">
#       window.googletag = window.googletag || {};
#   window.googletag.cmd = window.googletag.cmd || [];
#   window.ads_library = window.ads_library || { initialized: false };
#   window.ab_testing = window.ab_testing || [];
#   window.ab_testing.push('ADS-614_1');
#   window.hp_cln = window.hp_cln || false;
#   window.gptAds = window.gptAds || {
#     gptadslots: {targets: []},
#     gptadslotsPreload: {targets: []},
#     gptadslotsPhotoGallery: {isLoaded: false, targets: [], preload: 2},
#     gptadslotsFullPhotoGallery: {isLoaded: false, targets: [], preload: 0},
#     gptadslotsSrpStickyMrect: {targets: []},
#     gptadslotsListViewOnly: {targets: []},
#     gptadslotsMCCTile: {targets: []},
#     gptadslotsMapViewOnly: {targets: []},
#     gptadslotsMCCModalMap: {targets: []},
#     gptadslotsLeadOverlayOnly: {targets: []},
#     gptadslotsOutOfPage: {targets: []},
#     gptadslotsQuickViewOnly: {isLoaded: false, targets: []},
#     gptadslotsQuickViewPropertyDetails: {isLoaded: false, targets: []},
#     gptadslotsQuickViewMap: {isLoaded: false, targets: []},
#     gptadslotsQuickViewMapExp: {isLoaded: false, targets: []},
#     gptadslotsPaymentOptionOnly: {isLoaded: false, targets: []},
#     gptadslotsCollapseCardMap: {isLoaded: false, targets: []},
#     gptadslotsEMP: {isLoaded: false, targets: []},
#     gptadslotsTracking: {targets: []},
#     gptadslotsCLN: {targets: []},
#     gptadslotsArticleTracking: {targets: []},
#     gptadslotsAFCALCModalList: {targets: []},
#     gptadslotsAFCALCModalMap: {targets: []},
#     gptadslotsPFILTERModalList: {targets: []},
#     gptadslotsPFILTERModalMap: {targets: []},
#     gptadslotsFios: {targets: []},
#     gptadslotsVetOnlyCalcMort: {isLoaded: false, targets: []},
#     gptadslotsVetOnlyCalcAfford: {isLoaded: false, targets: []},
#     gptadslotsLdpPropertyFeatures: {isLoaded: false, targets: []},
#     gptadslotsCommunityPhotoGallery: {isLoaded: false, targets: []},
#     gptadslotsCommunityPhotoGalleryLogo: {isLoaded: false, targets: []},
#     gptadslotsMCCModal: {isLoaded: false, targets: []},
#     gptadslotsVideoMrect: {targets: [], targetsWithName: [], loaded: [], isLoaded: false},
#     gptadslotsTILE1PreloadMapView: {targets: [], isLoaded: false},
#     gptadslotsTILE1PreloadListView: {targets: [], isLoaded: false},
#     gptadslotsQuickViewPreloadOnly: {isLoaded: false, targets: []},
#     gptadslotsTXTINMapView: {targets: [], loaded: []},
#     gptadslotsTXTINListView: {targets: [], loaded: []},
#     quickview_targeting: {},
#     pageName: ""
#   };
#      </script>
#      <script type="text/javascript">
#       window.gptAds.pageName = '/8058/RDC2/LDP/SALE';
#     window.amazon_slots = [];
#     window.gptAds.pagePath = 'RDC2/LDP/SALE';
#     window.gptAds.device = 'DESK';
#     window.gptAds.adsPath = '/8058/';
#     var defineAdSlots = function () {
#       googletag.cmd.push(function() {
#         window.gptAds.gptadslotsOutOfPage.targets[0] = googletag.defineOutOfPageSlot('/8058/OOP/RDC2/LDP/SALE/DESK', 'div-gpt-ad-oop').addService(googletag.pubads()).setTargeting('pos',['OOP']).setTargeting('dap', ['y']);
#           var mappingLB2 = googletag.sizeMapping()
#                 .addSize([768, 100], [[728, 90], [1, 1]])
#               .build();
#         window.gptAds.gptadslots.targets[1] = googletag.defineSlot('/8058/LB2/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-LB2').addService(googletag.pubads())
#           .setTargeting('pos', ['LB2']).setTargeting('programmatic', [true]).defineSizeMapping(mappingLB2);
#           var mappingINLINE1 = googletag.sizeMapping()
#                 .addSize([768, 100], [[1, 1]])
#                 .addSize([320, 100], [[300, 250], [1, 1], "fluid"])
#               .build();
#         window.gptAds.gptadslots.targets[2] = googletag.defineSlot('/8058/INLINE1/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-INLINE1').addService(googletag.pubads())
#           .setTargeting('pos', ['INLINE1']).setTargeting('programmatic', [true]).defineSizeMapping(mappingINLINE1);
#           var mappingINLINE2 = googletag.sizeMapping()
#                 .addSize([768, 100], [[1, 1]])
#                 .addSize([320, 100], [[300, 250], [1, 1], "fluid"])
#               .build();
#         window.gptAds.gptadslots.targets[3] = googletag.defineSlot('/8058/INLINE2/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-INLINE2').addService(googletag.pubads())
#           .setTargeting('pos', ['INLINE2']).setTargeting('programmatic', [true]).defineSizeMapping(mappingINLINE2);
#           var mappingMRECT1 = googletag.sizeMapping()
#                 .addSize([996, 100], [[300, 250], [300, 600], [1, 1]])
#               .build();
#         window.gptAds.gptadslots.targets[4] = googletag.defineSlot('/8058/RR1/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-MRECT1').addService(googletag.pubads())
#           .setTargeting('pos', ['MRECT1', 'HPA1']).setTargeting('programmatic', [true]).defineSizeMapping(mappingMRECT1);
#             window.amazon_slots.push(
#               {
#                 slotID: 'div-gpt-ad-MRECT1',
#                 slotName: '/8058/RR1/RDC2/LDP/SALE/DESK',
#                 size_mappings: mappingMRECT1,
#                 sizes: []
#               }
#             );
#           var mappingMRECT2 = googletag.sizeMapping()
#                 .addSize([996, 100], [[300, 250], [300, 251], [300, 600], [1, 1]])
#               .build();
#         window.gptAds.gptadslots.targets[5] = googletag.defineSlot('/8058/RR2/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-MRECT2').addService(googletag.pubads())
#           .setTargeting('pos', ['MRECT2']).setTargeting('programmatic', [true]).defineSizeMapping(mappingMRECT2);
#             window.amazon_slots.push(
#               {
#                 slotID: 'div-gpt-ad-MRECT2',
#                 slotName: '/8058/RR2/RDC2/LDP/SALE/DESK',
#                 size_mappings: mappingMRECT2,
#                 sizes: []
#               }
#             );
#           var mappingBTNLEAD1 = googletag.sizeMapping()
#                 .addSize([320, 100], ["fluid"])
#               .build();
#         window.gptAds.gptadslotsLeadOverlayOnly.targets[6] = googletag.defineSlot('/8058/BTNLEAD1/RDC2/LEADCONFIRM/NA1/DESK', [], 'div-gpt-ad-BTNLEAD1').addService(googletag.pubads())
#           .setTargeting('pos', ['BTNLEAD1']).setTargeting('programmatic', [false]).defineSizeMapping(mappingBTNLEAD1);
#           var mappingMRECT3 = googletag.sizeMapping()
#                 .addSize([996, 100], [[300, 250], [300, 252], [300, 600], [1, 1]])
#               .build();
#         window.gptAds.gptadslots.targets[7] = googletag.defineSlot('/8058/RR3/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-MRECT3').addService(googletag.pubads())
#           .setTargeting('pos', ['MRECT3', 'HPA3', 'PORT3']).setTargeting('programmatic', [true]).defineSizeMapping(mappingMRECT3);
#             window.amazon_slots.push(
#               {
#                 slotID: 'div-gpt-ad-MRECT3',
#                 slotName: '/8058/RR3/RDC2/LDP/SALE/DESK',
#                 size_mappings: mappingMRECT3,
#                 sizes: []
#               }
#             );
#           var mappingMAPLDP1 = googletag.sizeMapping()
#                 .addSize([1260, 100], [[728, 90], [728, 92], [1, 1]])
#                 .addSize([996, 100], [[1, 1]])
#                 .addSize([768, 100], [[728, 90], [728, 92], [1, 1]])
#                 .addSize([320, 100], [[320, 50], [320, 100], [300, 250], [300, 251], [1, 1]])
#               .build();
#         window.gptAds.gptadslots.targets[8] = googletag.defineSlot('/8058/MAPLDP1/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-MAPLDP1').addService(googletag.pubads())
#           .setTargeting('pos', ['MAPLDP1']).setTargeting('programmatic', [true]).defineSizeMapping(mappingMAPLDP1);
#             window.amazon_slots.push(
#               {
#                 slotID: 'div-gpt-ad-MAPLDP1',
#                 slotName: '/8058/MAPLDP1/RDC2/LDP/SALE/DESK',
#                 size_mappings: mappingMAPLDP1,
#                 sizes: []
#               }
#             );
#           var mappingPHOTOMRECT1 = googletag.sizeMapping()
#                 .addSize([1280, 100], [[300, 250], [300, 253], [728, 90], [645, 400], [760, 400], [1, 1], "fluid"])
#                 .addSize([320, 100], [[300, 250], [300, 253], [1, 1], "fluid"])
#               .build();
#         window.gptAds.gptadslotsPhotoGallery.targets[9] = googletag.defineSlot('/8058/PHOTOMRECT1/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-PHOTOMRECT1').addService(googletag.pubads())
#           .setTargeting('pos', ['PHOTOMRECT1']).setTargeting('programmatic', [true]).defineSizeMapping(mappingPHOTOMRECT1);
#           var mappingPHOTOMRECT2 = googletag.sizeMapping()
#                 .addSize([996, 100], [[970, 66], [970, 250], [810, 600], [760, 400], [728, 90], [645, 480], [300, 250], [300, 254], [1, 1], "fluid"])
#                 .addSize([320, 100], [[320, 525], [300, 250], [300, 254], [1, 1], "fluid"])
#               .build();
#         window.gptAds.gptadslotsFullPhotoGallery.targets[10] = googletag.defineSlot('/8058/PHOTOMRECT2/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-PHOTOMRECT2').addService(googletag.pubads())
#           .setTargeting('pos', ['PHOTOMRECT2']).setTargeting('programmatic', [true]).defineSizeMapping(mappingPHOTOMRECT2);
#           var mappingTXTLDP1 = googletag.sizeMapping()
#                 .addSize([768, 100], [[500, 15], [400, 15], [400, 17], [1, 1]])
#                 .addSize([320, 100], [[300, 15], [300, 17], [300, 50], [1, 1]])
#               .build();
#         window.gptAds.gptadslotsPreload.targets[11] = googletag.defineSlot('/8058/TXTLDP1/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-TXTLDP1').addService(googletag.pubads())
#           .setTargeting('pos', ['TXTLDP1']).setTargeting('programmatic', [false]).defineSizeMapping(mappingTXTLDP1);
#           var mappingTXTLDP1B = googletag.sizeMapping()
#                 .addSize([1260, 100], ["fluid", [1, 1]])
#               .build();
#         window.gptAds.gptadslotsPreload.targets[12] = googletag.defineSlot('/8058/TXTLDP1B/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-TXTLDP1B').addService(googletag.pubads())
#           .setTargeting('fullLdp', ['fullldp']).setTargeting('pos', ['TXTLDP1B']).setTargeting('programmatic', [false]).defineSizeMapping(mappingTXTLDP1B);
#         window.gptAds.gptadslots.targets[13] = googletag.defineSlot('/8058/MAPAD4/RDC2/LDP/SALE/DESK', [[1, 1]], 'div-gpt-ad-MAPAD4').addService(googletag.pubads())
#           .setTargeting('pos', ['MAPAD4']).setTargeting('programmatic', [false]);
#           var mappingTXTLDP3 = googletag.sizeMapping()
#                 .addSize([768, 100], [[550, 15], [550, 35], [300, 15], [1, 1]])
#                 .addSize([320, 100], [[300, 35], [300, 15], [300, 17], [1, 1]])
#               .build();
#         window.gptAds.gptadslotsPreload.targets[14] = googletag.defineSlot('/8058/TXTLDP3/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-TXTLDP3').addService(googletag.pubads())
#           .setTargeting('pos', ['TXTLDP3']).setTargeting('programmatic', [false]).defineSizeMapping(mappingTXTLDP3);
#         window.gptAds.gptadslotsTracking.targets[15] = googletag.defineSlot('/8058/PIXEL/RDC2/LDP/SALE/DESK', [[1, 1]], 'div-gpt-ad-PIXEL').addService(googletag.pubads())
#           .setTargeting('pos', ['PIXEL']).setTargeting('programmatic', [false]);
#           var mappingTXTPYMT1 = googletag.sizeMapping()
#                 .addSize([768, 100], [[260, 20], [260, 40], [1, 1]])
#                 .addSize([320, 100], [[300, 20], [300, 40], [1, 1]])
#               .build();
#         window.gptAds.gptadslotsEMP.targets[16] = googletag.defineSlot('/8058/TXTPYMT1/RDC2/PYMT/NA1/DESK', [], 'div-gpt-ad-TXTPYMT1').addService(googletag.pubads())
#           .setTargeting('pos', ['TXTPYMT1']).setTargeting('programmatic', [false]).defineSizeMapping(mappingTXTPYMT1);
#           var mappingTXTPYMT2 = googletag.sizeMapping()
#                 .addSize([768, 100], [[290, 40], [1, 1]])
#                 .addSize([320, 100], [[290, 20], [290, 40], [290, 50], [1, 1]])
#               .build();
#         window.gptAds.gptadslotsEMP.targets[17] = googletag.defineSlot('/8058/TXTPYMT2/RDC2/PYMT/NA1/DESK', [], 'div-gpt-ad-TXTPYMT2').addService(googletag.pubads())
#           .setTargeting('pos', ['TXTPYMT2']).setTargeting('programmatic', [false]).defineSizeMapping(mappingTXTPYMT2);
#           var mappingLBPYMT1 = googletag.sizeMapping()
#                 .addSize([768, 100], [[728, 90], [728, 91], [1, 1]])
#                 .addSize([320, 100], [[300, 250], [320, 50], [320, 100], [1, 1]])
#               .build();
#         window.gptAds.gptadslotsEMP.targets[18] = googletag.defineSlot('/8058/LBPYMT1/RDC2/PYMT/NA1/DESK', [], 'div-gpt-ad-LBPYMT1').addService(googletag.pubads())
#           .setTargeting('pos', ['LBPYMT1']).setTargeting('programmatic', [true]).defineSizeMapping(mappingLBPYMT1);
#           var mappingMCCLOGO1 = googletag.sizeMapping()
#                 .addSize([996, 100], [[88, 31], [1, 1]])
#               .build();
#         window.gptAds.gptadslots.targets[19] = googletag.defineSlot('/8058/MCCLOGO1/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-MCCLOGO1').addService(googletag.pubads())
#           .setTargeting('pos', ['MCCLOGO1']).setTargeting('programmatic', [false]).defineSizeMapping(mappingMCCLOGO1);
#           var mappingMCCLOGO2 = googletag.sizeMapping()
#                 .addSize([768, 100], [[88, 31], [1, 1]])
#               .build();
#         window.gptAds.gptadslotsMCCModal.targets[20] = googletag.defineSlot('/8058/MCCLOGO2/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-MCCLOGO2').addService(googletag.pubads())
#           .setTargeting('pos', ['MCCLOGO2']).setTargeting('programmatic', [false]).defineSizeMapping(mappingMCCLOGO2);
#           var mappingMCCMRECT1 = googletag.sizeMapping()
#                 .addSize([768, 100], [[300, 250], [1, 1]])
#               .build();
#         window.gptAds.gptadslotsMCCModal.targets[21] = googletag.defineSlot('/8058/MCCMRECT1/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-MCCMRECT1').addService(googletag.pubads())
#           .setTargeting('pos', ['MCCMRECT1']).setTargeting('programmatic', [false]).defineSizeMapping(mappingMCCMRECT1);
#           var mappingTXTMORT1 = googletag.sizeMapping()
#                 .addSize([768, 100], [[380, 30], [500, 30], [1, 1]])
#                 .addSize([320, 100], [[300, 30], [300, 50], [1, 1]])
#               .build();
#         window.gptAds.gptadslots.targets[22] = googletag.defineSlot('/8058/TXTMORT1/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-TXTMORT1').addService(googletag.pubads())
#           .setTargeting('pos', ['TXTMORT1']).setTargeting('programmatic', [false]).defineSizeMapping(mappingTXTMORT1);
#           var mappingNEIGHLDP1 = googletag.sizeMapping()
#                 .addSize([320, 100], [[1, 1], "fluid"])
#               .build();
#         window.gptAds.gptadslots.targets[23] = googletag.defineSlot('/8058/NEIGHLDP1/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-NEIGHLDP1').addService(googletag.pubads())
#           .setTargeting('pos', ['NEIGHLDP1']).setTargeting('programmatic', [false]).defineSizeMapping(mappingNEIGHLDP1);
#           var mappingHOMSVC1 = googletag.sizeMapping()
#                 .addSize([320, 100], [[1, 1], "fluid"])
#               .build();
#         window.gptAds.gptadslotsLdpPropertyFeatures.targets[24] = googletag.defineSlot('/8058/HOMSVC1/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-HOMSVC1').addService(googletag.pubads())
#           .setTargeting('pos', ['HOMSVC1']).setTargeting('programmatic', [false]).defineSizeMapping(mappingHOMSVC1);
#           var mappingHOMSVC2 = googletag.sizeMapping()
#                 .addSize([320, 100], [[1, 1], "fluid"])
#               .build();
#         window.gptAds.gptadslotsLdpPropertyFeatures.targets[25] = googletag.defineSlot('/8058/HOMSVC2/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-HOMSVC2').addService(googletag.pubads())
#           .setTargeting('pos', ['HOMSVC2']).setTargeting('programmatic', [false]).defineSizeMapping(mappingHOMSVC2);
#           var mappingHOMSVC3 = googletag.sizeMapping()
#                 .addSize([320, 100], [[1, 1], "fluid"])
#               .build();
#         window.gptAds.gptadslotsLdpPropertyFeatures.targets[26] = googletag.defineSlot('/8058/HOMSVC3/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-HOMSVC3').addService(googletag.pubads())
#           .setTargeting('pos', ['HOMSVC3']).setTargeting('programmatic', [false]).defineSizeMapping(mappingHOMSVC3);
#           var mappingTXTMORT2 = googletag.sizeMapping()
#                 .addSize([768, 100], [[380, 30], [380, 31], [1, 1]])
#                 .addSize([320, 100], [[300, 30], [300, 31], [1, 1]])
#               .build();
#         window.gptAds.gptadslots.targets[27] = googletag.defineSlot('/8058/TXTMORT2/RDC2/LDP/SALE/DESK', [], 'div-gpt-ad-TXTMORT2').addService(googletag.pubads())
#           .setTargeting('pos', ['TXTMORT2']).setTargeting('programmatic', [false]).defineSizeMapping(mappingTXTMORT2);
#             googletag.pubads().setTargeting('address',['11400_MIDBURY_CT']);
#             googletag.pubads().setTargeting('cityldp',['AUSTIN']);
#             googletag.pubads().setTargeting('st',['TX']);
#             googletag.pubads().setTargeting('citystldp',['AUSTIN_TX']);
#             googletag.pubads().setTargeting('zipldp',['78748']);
#             googletag.pubads().setTargeting('countyldp',['48453']);
#             googletag.pubads().setTargeting('mlid',['2692213958']);
#             googletag.pubads().setTargeting('mprid',['7863175807']);
#             googletag.pubads().setTargeting('bedldp',['4']);
#             googletag.pubads().setTargeting('bathldp',['2.5']);
#             googletag.pubads().setTargeting('openldp',['TRUE']);
#             googletag.pubads().setTargeting('rdpr',['FALSE']);
#             googletag.pubads().setTargeting('t',['BL']);
#             googletag.pubads().setTargeting('add',['092719']);
#             googletag.pubads().setTargeting('lstat',['NEW']);
#             googletag.pubads().setTargeting('lotldp',['.5']);
#             googletag.pubads().setTargeting('sqft',['2834']);
#             googletag.pubads().setTargeting('sqldp',['2500_2999']);
#             googletag.pubads().setTargeting('agehom',['5']);
#             googletag.pubads().setTargeting('office_advertiser_id',['2976616']);
#             googletag.pubads().setTargeting('agent_advertiser_id',['3318020']);
#             googletag.pubads().setTargeting('mls',['1392127']);
#             googletag.pubads().setTargeting('bkr',['OTHER']);
#             googletag.pubads().setTargeting('listingprice',['308900']);
#             googletag.pubads().setTargeting('pldp',['250K_500K','85K','250K','300K']);
#             googletag.pubads().setTargeting('ptldp',['1']);
#             googletag.pubads().setTargeting('pfldp',['CA','FAMRM','SEWER']);
#             googletag.pubads().setTargeting('garageldp',['2']);
#             googletag.pubads().setTargeting('opensrch',['FALSE']);
#             googletag.pubads().setTargeting('ptsrch',['0']);
#             googletag.pubads().setTargeting('jy',['D05B18BC264443A3B47644EE41E97974']);
#             googletag.pubads().setTargeting('vst',['D05B18BC-2644-43A3-B476-44EE41E97974']);
#             googletag.pubads().setTargeting('split',['26']);
#             googletag.pubads().setTargeting('split_tcv',['101']);
#             googletag.pubads().setTargeting('platform',['WEB_DESK']);
#             googletag.pubads().setTargeting('basecamp',['TRUE']);
#             googletag.pubads().setTargeting('disable_vu',['FALSE']);
#         if (window.ab_testing) {
#           googletag.pubads().setTargeting('variant', window.ab_testing);
#         }
#         var tracking = [];
#         var all_tests_on_page = document.querySelectorAll('[id^="ab_id_"]');
#         for (var i = 0, len = all_tests_on_page.length; i < len; i++) {
#           tracking.push(all_tests_on_page[i].dataset['optimizely']);
#         }
#         if (tracking.length >= 1){
#           googletag.pubads().setTargeting('OPTMZVAR', tracking.join(","));
#         }
#         googletag.pubads().enableAsyncRendering();
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().collapseEmptyDivs();
#         googletag.pubads().disableInitialLoad();
#         googletag.enableServices();
#         window.ads_library.initialized = true;
#       });
#     };
#     var preloadAds = function() {
#       googletag.cmd.push(function() {
#         window.gptAds.gptadslotsPreload.targets.forEach(function(slot) {
#           googletag.display(slot.getSlotElementId());
#         });
#         googletag.pubads().refresh(window.gptAds.gptadslotsPreload.targets);
#       });
#     };
#
#     var preloadTile1AdForView = function(adSlotForView) {
#       adSlotForView.targets.forEach(function(slot) {
#         if (!adSlotForView.isLoaded){
#           googletag.display(slot.getSlotElementId());
#         }
#       });
#       googletag.pubads().refresh(adSlotForView.targets);
#       adSlotForView.isLoaded = true;
#       window.SRPPreloadTile1Ad = true;
#     };
#
#     var mapView = function() {
#       var body = document.getElementsByTagName("BODY");
#       if (body.length) {
#         return body[0].classList.contains('ab-mixed-view');
#       }
#       return false;
#     };
#
#     var preloadTile1Ad = function(view) {
#       googletag.cmd.push(function() {
#         if (view === 'list') {
#           if (!mapView())
#             preloadTile1AdForView(window.gptAds.gptadslotsTILE1PreloadListView);
#         }
#         else {
#           if (mapView())
#             preloadTile1AdForView(window.gptAds.gptadslotsTILE1PreloadMapView);
#         }
#       });
#     };
#
#     var setFluidTileAd = function(adUnit) {
#       try
#       {
#         let adDivId = 'div-gpt-ad-TILE';
#         adDivId += mapView() ? 'MAP' : 'LIST';
#         adDivId = adUnit.replace('TILE', adDivId);
#         let tileAd = document.getElementById(adDivId);
#         if (tileAd) {
#           tileAd.parentElement.parentElement.classList.add("fluid_tile_ad");
#         }
#       }
#       catch(e) { /* ignore */ }
#     };
#
#     var setTxtLdp1bAdWidth = function(width) {
#       var widthPx = width + 'px';
#       var txtldp1bAd = document.getElementById('div-gpt-ad-TXTLDP1B');
#       txtldp1bAd.style.width = widthPx;
#       var adDivs = txtldp1bAd.getElementsByTagName("div");
#       if (adDivs.length) {
#         adDivs[0].style.width = widthPx;
#       }
#       setTimeout(
#         function() {
#           txtldp1bAd.classList.remove("TXTLDPLoading");
#           document.getElementById('div-gpt-ad-TXTLDP1').classList.remove("TXTLDPLoading");
#         }, 300
#       );
#     };
#
#     var handlePreloadAdsMessage = function (event) {
#       try
#       {
#         let origin = event.origin || event.originalEvent.origin;
#         //tpc.googlesyndication.com is another CDN of gpt ads static files
#         if (origin === 'http://tpc.googlesyndication.com' || origin === 'https://tpc.googlesyndication.com') {
#           let jsonMsg = JSON.parse(event.data);
#           switch (jsonMsg.type) {
#             case 'FLUIDTILE':
#               setFluidTileAd(jsonMsg.ad_unit);
#               break;
#             case 'TXTLDP1B':
#               setTxtLdp1bAdWidth(jsonMsg.width);
#               break;
#           }
#         }
#       }
#       catch(e) { /* ignore */ }
#     };
#
#     defineAdSlots();
#     window.addEventListener("message", handlePreloadAdsMessage, false);
#      </script>
#      <meta content="11400 Midbury Ct, Austin, TX 78748 - realtor.com®" property="og:title"/>
#      <meta content="realtor.com®" property="og:site_name"/>
#      <meta content="Large butlers pantry with space | View 40 photos of this 4 bed, 2+ bath, 2,834 Sq. Ft. single family home at 11400 Midbury Ct, Austin, TX 78748 on sale now for $308,900." property="og:description"/>
#      <meta content="place" property="og:type"/>
#      <meta content="https://ap.rdcpix.com/236830441/a915943ce8fc1e414062e79dabd54b47l-m0xd-w640_h480_q80.jpg" property="og:image"/>
#      <meta content="640" property="og:image:width"/>
#      <meta content="480" property="og:image:height"/>
#      <meta content="11400 Midbury Ct" property="og:street-address"/>
#      <meta content="Austin" property="og:locality"/>
#      <meta content="TX" property="og:region"/>
#      <meta content="78748" property="og:postal-code"/>
#      <meta content="USA" property="og:country-name"/>
#      <meta content="30.156801" property="place:location:latitude"/>
#      <meta content="-97.842946" property="place:location:longitude"/>
#      <meta content="https://www.realtor.com/realestateandhomes-detail/11400-Midbury-Ct_Austin_TX_78748_M78631-75807" property="og:url"/>
#      <meta content="summary_large_image" name="twitter:card"/>
#      <meta content="@realtordotcom" name="twitter:site"/>
#      <meta content="@realtordotcom" name="twitter:creator"/>
#      <meta content="11400 Midbury Ct, Austin, TX 78748 - realtor.com®" name="twitter:title"/>
#      <meta content="Large butlers pantry with space | View 40 photos of this 4 bed, 2+ bath, 2,834 Sq. Ft. single family home at 11400 Midbury Ct, Austin, TX 78748 on sale now for $308,900." name="twitter:description"/>
#      <meta content="https://ap.rdcpix.com/236830441/a915943ce8fc1e414062e79dabd54b47l-m0xd-w640_h480_q80.jpg" name="twitter:image"/>
#      <link href="ios-app://336698281/move-rdc/www.realtor.com/realestateandhomes-detail/11400-Midbury-Ct_Austin_TX_78748_M78631-75807" rel="alternate">
#       <link href="android-app://com.move.realtor/move-rdc/www.realtor.com/realestateandhomes-detail/11400-Midbury-Ct_Austin_TX_78748_M78631-75807" rel="alternate">
#        <script>
#         (function() {
#         window.markAs = function() {
#             var perfAPI = window.performance;
#             if (perfAPI && perfAPI.mark) {
#                 for (let i = 0; i < arguments.length; i++) {
#                     perfAPI.mark(arguments[i])
#                 }
#             }
#         };
#     })();
#        </script>
#       </link>
#      </link>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body class="property_details show" data-offset="160" data-spy="scroll" data-target="#sticky-bar-scroll-spy">
#   <script type="text/javascript">
#    //<![CDATA[
#         window.gon = { MOVE_DATA: {"ab_cta_text_submit":"C1","ab_hlt_price_drop":"C1","ab_desktop_text":null,"ab_desktop_text_variation":null,"ab_schedule_tour":"C1","ab_img_ctr_swap":"C1","ab_vitality":false,"ab_vitality_count":"C1","app_js":["//static.rdc-next-basecamp.rdc.moveaws.com/assets/packs/application_non_critical-e7ec28cac8399dc90e55.js","//static.rdc-next-basecamp.rdc.moveaws.com/assets/packs/ldp_non_critical-b47f0530dba729478ef7.js"],"railsEnvironment":"production","assetHost":"static.rdc-next-basecamp.rdc.moveaws.com","suggestApiEndPoint":"https://parser-external.geo.moveaws.com/suggest","isPhone":null,"isTablet":false,"isIE":null,"isEdge":null,"isIosOrAndroid":false,"isAndroid":false,"branch_device_info":null,"isDesktop":true,"supads":null,"pageType":"ldp","schoolDistrictEnabled":true,"ab_similar_homes_type_ldp":"similar_homes_ml","ab_similar_homes_type_pdp":"similar_homes_for_sale","consider_variation":null,"abSwap":"control","ab_qv_open_card":"C1","ab_text_lead_form_img":null,"ab_hide_lead_msg_text":"C1","ab_tcpa_combined":"C1","ab_lead_name":true,"ab_dtop_chat":"control","ab_mid_gallery_cta":false,"leadHeaderTitleExp":"C1","ab_lead_title":"More about this property","ft_inline_cta_is_enabled":true,"flg_inline_cta":"Email Agent","ft_leadform_cta_is_enabled":true,"flg_leadform_cta":"Email Agent","propertyDetails":{"property_id":7863175807,"listing_id":2692213958,"saved_resource_id":null,"status":"for_sale","status_display":"Home For Sale","property_type":"for_sale","headline":null,"lat":30.156801,"long":-97.842946,"address":"11400 Midbury Ct","city":"Austin","mlslid":null,"state_code":"TX","postal_code":"78748","price":308900,"price_display":"$308,900","product_type":"cobroke","community_id":null,"id":null,"photo_count":40,"permalink":"11400-Midbury-Ct_Austin_TX_78748_M78631-75807","lead_attributes":{"form_type":"classic","lead_type":"co_broke","show_contact_an_agent":true,"show_text_leads":true,"show_contact_a_lender":true,"is_lcm_enabled":false,"flip_the_market_enabled":false,"show_veterans_united":true,"cashback_enabled":false},"source_id":null,"type":"single_family","type_display":"Single Family Home","prop_type":null,"edited_facts":null,"public_record":null,"name":null,"is_cobroke":true,"is_showcase":false,"is_office_standard":false,"is_suppress_map_pin":false,"is_pre_approved":true,"is_address_suppressed":false,"is_foreclosure":false,"print_photos":[{"url":"https://ap.rdcpix.com/236830441/a915943ce8fc1e414062e79dabd54b47l-m0xd-w640_h480_q80.jpg","description":"","type":null,"tags":[{"label":"exterior","probability":0.587,"href":"https://ap.rdcpix.com/236830441/a915943ce8fc1e414062e79dabd54b47l-m0xd-w300_h300_q80.jpg"},{"label":"street_view","probability":0.411},{"label":"bedroom","probability":0.001}]},{"url":"https://ap.rdcpix.com/2620594234/a915943ce8fc1e414062e79dabd54b47l-m1xd-w640_h480_q80.jpg","description":"","type":null,"tags":[{"label":"kitchen","probability":0.987,"href":"https://ap.rdcpix.com/2620594234/a915943ce8fc1e414062e79dabd54b47l-m1xd-w300_h300_q80.jpg"},{"label":"bathroom","probability":0.006},{"label":"unknown","probability":0.005}]},{"url":"https://ap.rdcpix.com/1196788260/a915943ce8fc1e414062e79dabd54b47l-m2xd-w640_h480_q80.jpg","description":"","type":null,"tags":[{"label":"kitchen","probability":0.935,"href":"https://ap.rdcpix.com/1196788260/a915943ce8fc1e414062e79dabd54b47l-m2xd-w300_h300_q80.jpg"},{"label":"bathroom","probability":0.056},{"label":"unknown","probability":0.007}]},{"url":"https://ap.rdcpix.com/3890496272/a915943ce8fc1e414062e79dabd54b47l-m3xd-w640_h480_q80.jpg","description":"","type":null,"tags":[{"label":"bedroom","probability":0.644,"href":"https://ap.rdcpix.com/3890496272/a915943ce8fc1e414062e79dabd54b47l-m3xd-w300_h300_q80.jpg"},{"label":"unknown","probability":0.302},{"label":"living_room","probability":0.043}]}],"agent_adv_id":3318020,"broker_adv_id":2976616,"advertiser_id":2976616,"map":{"google_maps_api_key":"","google_maps_client_id":"gme-movesalesinc","go ...
#         MOVE_DATA = {"ab_cta_text_submit":"C1","ab_hlt_price_drop":"C1","ab_desktop_text":null,"ab_desktop_text_variation":null,"ab_schedule_tour":"C1","ab_img_ctr_swap":"C1","ab_vitality":false,"ab_vitality_count":"C1","app_js":["//static.rdc-next-basecamp.rdc.moveaws.com/assets/packs/application_non_critical-e7ec28cac8399dc90e55.js","//static.rdc-next-basecamp.rdc.moveaws.com/assets/packs/ldp_non_critical-b47f0530dba729478ef7.js"],"railsEnvironment":"production","assetHost":"static.rdc-next-basecamp.rdc.moveaws.com","suggestApiEndPoint":"https://parser-external.geo.moveaws.com/suggest","isPhone":null,"isTablet":false,"isIE":null,"isEdge":null,"isIosOrAndroid":false,"isAndroid":false,"branch_device_info":null,"isDesktop":true,"supads":null,"pageType":"ldp","schoolDistrictEnabled":true,"ab_similar_homes_type_ldp":"similar_homes_ml","ab_similar_homes_type_pdp":"similar_homes_for_sale","consider_variation":null,"abSwap":"control","ab_qv_open_card":"C1","ab_text_lead_form_img":null,"ab_hide_lead_msg_text":"C1","ab_tcpa_combined":"C1","ab_lead_name":true,"ab_dtop_chat":"control","ab_mid_gallery_cta":false,"leadHeaderTitleExp":"C1","ab_lead_title":"More about this property","ft_inline_cta_is_enabled":true,"flg_inline_cta":"Email Agent","ft_leadform_cta_is_enabled":true,"flg_leadform_cta":"Email Agent","propertyDetails":{"property_id":7863175807,"listing_id":2692213958,"saved_resource_id":null,"status":"for_sale","status_display":"Home For Sale","property_type":"for_sale","headline":null,"lat":30.156801,"long":-97.842946,"address":"11400 Midbury Ct","city":"Austin","mlslid":null,"state_code":"TX","postal_code":"78748","price":308900,"price_display":"$308,900","product_type":"cobroke","community_id":null,"id":null,"photo_count":40,"permalink":"11400-Midbury-Ct_Austin_TX_78748_M78631-75807","lead_attributes":{"form_type":"classic","lead_type":"co_broke","show_contact_an_agent":true,"show_text_leads":true,"show_contact_a_lender":true,"is_lcm_enabled":false,"flip_the_market_enabled":false,"show_veterans_united":true,"cashback_enabled":false},"source_id":null,"type":"single_family","type_display":"Single Family Home","prop_type":null,"edited_facts":null,"public_record":null,"name":null,"is_cobroke":true,"is_showcase":false,"is_office_standard":false,"is_suppress_map_pin":false,"is_pre_approved":true,"is_address_suppressed":false,"is_foreclosure":false,"print_photos":[{"url":"https://ap.rdcpix.com/236830441/a915943ce8fc1e414062e79dabd54b47l-m0xd-w640_h480_q80.jpg","description":"","type":null,"tags":[{"label":"exterior","probability":0.587,"href":"https://ap.rdcpix.com/236830441/a915943ce8fc1e414062e79dabd54b47l-m0xd-w300_h300_q80.jpg"},{"label":"street_view","probability":0.411},{"label":"bedroom","probability":0.001}]},{"url":"https://ap.rdcpix.com/2620594234/a915943ce8fc1e414062e79dabd54b47l-m1xd-w640_h480_q80.jpg","description":"","type":null,"tags":[{"label":"kitchen","probability":0.987,"href":"https://ap.rdcpix.com/2620594234/a915943ce8fc1e414062e79dabd54b47l-m1xd-w300_h300_q80.jpg"},{"label":"bathroom","probability":0.006},{"label":"unknown","probability":0.005}]},{"url":"https://ap.rdcpix.com/1196788260/a915943ce8fc1e414062e79dabd54b47l-m2xd-w640_h480_q80.jpg","description":"","type":null,"tags":[{"label":"kitchen","probability":0.935,"href":"https://ap.rdcpix.com/1196788260/a915943ce8fc1e414062e79dabd54b47l-m2xd-w300_h300_q80.jpg"},{"label":"bathroom","probability":0.056},{"label":"unknown","probability":0.007}]},{"url":"https://ap.rdcpix.com/3890496272/a915943ce8fc1e414062e79dabd54b47l-m3xd-w640_h480_q80.jpg","description":"","type":null,"tags":[{"label":"bedroom","probability":0.644,"href":"https://ap.rdcpix.com/3890496272/a915943ce8fc1e414062e79dabd54b47l-m3xd-w300_h300_q80.jpg"},{"label":"unknown","probability":0.302},{"label":"living_room","probability":0.043}]}],"agent_adv_id":3318020,"broker_adv_id":2976616,"advertiser_id":2976616,"map":{"google_maps_api_key":"","google_maps_client_id":"gme-movesalesinc","google_maps_vers ...
#     //]]>
#   </script>
#   <!-- Loading invision header depanding on parameter is_invision_app -->
#   <div class="hide" id="invision_app_content">
#    <div class="global-nav-invision-app" id="invision_header">
#     <div class="invision-wrapper-links-main">
#      <div class="container">
#       <ul class="invision-left-links">
#        <li>
#         <a data-omtag="" href="https://dashboard.realtor.com" target="_blank">
#          Go to your professional dashboard
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="global-header-invision-line">
#     </div>
#    </div>
#   </div>
#   <!-- To avoid  delay in time for sprite-header.svg -->
#   <img alt="header sprite" id="header-sprite" src="" style="display:none"/>
#   <!--BEGIN QUALTRICS SITE INTERCEPT-->
#   <!-- commented out for the time being -->
#   <!-- <div id='ZN_8p1dPH4RgQzWV0x'></div> -->
#   <!--End QUALTRICS SITE INTERCEPT -->
#   <nav class="global-navbar global-navbar-default global-nav-header" id="header-navbar">
#    <div class="container">
#     <div class="global-navbar-header">
#      <button class="global-navbar-toggle" id="header-menu-btn">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#      <a class="global-navbar-brand header-rdc-logo" data-no-turbolink="true" data-omtag="header-menu:network:realtor" href="/" id="header-rdc-logo" title="Go to realtor.com home page">
#       <svg height="29" viewbox="0 0 445 82" width="156" xmlns="http://www.w3.org/2000/svg">
#        <g fill="none" fill-rule="evenodd">
#         <path d="M31.802 41.716c-2.77 0-4.27-1.202-5.08-3.396-.806-2.077-.575-3.05-2.654-3.05-2.077 0-6.925 5.716-7.618 13.562-.115.925-.23 6.118-.23 9.005v7.08c0 3.116-.23 7.042.346 9.35.577 3.117 1.385 3.462 3.81 4.5.807.35 1.154.463 1.73.577v.232H.522v-.232c.462-.114.924-.228 1.73-.576 2.426-1.04 3.118-1.384 3.695-4.5.577-2.31.347-6.235.347-9.35V44.83c0-1.96.115-7.502-.116-9.232-.346-2.193-.923-2.886-1.963-3.694-1.153-.923-2.307-.923-3-1.04v-.23h14.428c.692 0 .692.23.692.692l-.115 13.16h.115c1.385-5.772 4.386-9.465 6-11.08 1.618-1.732 4.62-3.81 8.313-3.81 1.73 0 3.694.462 4.963 1.847.925.92 1.617 2.422 1.617 4.85 0 2.766-1.73 5.42-5.425 5.42" fill="#D52331">
#         </path>
#         <path d="M248.39 41.716c-2.77 0-4.27-1.202-5.08-3.396-.807-2.077-.576-3.05-2.652-3.05-2.08 0-6.926 5.716-7.62 13.562-.115.925-.232 6.118-.232 9.005v7.08c0 3.116-.23 7.042.35 9.35.576 3.117 1.383 3.462 3.807 4.5.808.35 1.154.463 1.732.577v.232H217.11v-.232c.462-.114.925-.228 1.73-.576 2.425-1.04 3.118-1.384 3.695-4.5.577-2.31.345-6.
#         <path d="M174.58 73.227c-1.73 3.808-6.81 7.386-11.773 7.386-4.5 0-7.5-.69-10.04-3-2.08-1.847-3.002-4.154-3.002-8.424 0-2.31.346-32.205.462-37.862-1.732-.114-5.08-.114-6.81-.345v-.23c7.156-1.618 11.657-5.308 16.504-20.893h.35v19.112h11.426v2.242H160.27L159.805 70c0 4.385 1.27 8.153 5.886 8.153 4.04 0 7.158-2.387 8.542-5.155l.347.23" fill="#252521">
#         </path>
#         <path d="M201.703 35.208c-2.31-2.77-4.963-3.347-7.62-3.347-2.536 0-5.307.926-7.5 3.233-3.463 3.578-5.425 11.126-5.425 19.898 0 9.004 2.077 16.046 5.31 19.856 2.308 2.77 5.08 3.462 7.616 3.462 2.656 0 5.195-.575 7.62-3.346 3.115-3.81 5.308-10.968 5.308-19.97 0-8.89-2.076-15.976-5.31-19.784zm-7.62 45.405c-11.424 0-23.66-9.808-23.66-25.622 0-15.813 12.236-25.393 23.66-25.393 11.43 0 23.78 9.697 23.78 25.394 0 15.7-12.35 25.623-23.78 25.623zM335.707 35.208c-2.308-2.77-4.963-3.347-7.62-3.347-2.538 0-5.307.926-7.5 3.233-3.463 3.578-5.426 11.126-5.426 19.898 0 9.004 2.08 16.046 5.31 19.856 2.31 2.77 5.08 3.462 7.618 3.462 2.656 0 5.196-.575 7.62-3.346 3.117-3.81 5.31-10.968 5.31-19.97 0-8.89-2.08-15.976-5.31-19.784zm-7.62 45.405c-11.426 0-23.66-9.808-23.66-25.622 0-15.813 12.234-25.393 23.66-25.393 11.428 0 23.78 9.697 23.78 25.394 0 15.7-12.352 25.623-23.78 25.623zM254.22 81.307c-3.35 0-6.12-2.655-6.12-6.347 0-3.694 2.77-6.35 6.12-6.35 3.346 0 6.117 2.31 6.117 6.35 0 4.04-2.77 6.347-6.117 6.347M286.305 80.613c-6.348 0-12.004-2.42-15.696-6.116-4.732-4.846-6.58-11.66-6.58-19.966 0-15.7 12.004-24.933 22.392-24.933 7.154 0 12.465 2.656 14.542 5.195 1.617 1.963 2.427 3.694 2.427 5.308 0 3.58-2.656 4.965-4.734 4.965-3.923 0-5.31-2.425-5.77-6.118-.925-6.58-1.963-7.427-6.927-7.427-1.962 0-5.08.808-6.925 2.887-2.656 3-4.04 9.156-4.04 18.16 0 11.31 1.384 15.78 4.387 20.164 2.192 3.233 4.962 4.043 7.617 4.043 10.388 0 15.004-6.084 16.62-12.895l.46.116c-2.076 9.12-8.077 16.62-17.775 16.62" fill="#252521">
#         </path>
# ...
#           </div>
#          </div>
#         </div>
#         <div class="clearfix">
#          <div class="ad-marginless-modal">
#           <div class="ads" id="div-gpt-ad-LBPYMT1">
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="modal fade js-modal-lazyload-assets" id="ldp-fullscreen-map-mobile" role="dialog" tabindex="-1">
#      <div class="modal-dialog fsgallery-modal fsmap-mobile">
#       <div class="modal-content">
#        <div class="modal-header fs-map-mobile-header">
#         <div class="modal-header-wrapper">
#          <h2 class="font-size-small pull-left">
#           <span itemprop="streetAddress">
#            11400 Midbury Ct
#           </span>
#           <span itemprop="addressLocality">
#            Austin
#           </span>
#           ,
#           <span itemprop="addressRegion">
#            TX
#           </span>
#           <span class="margin-right-lg" itemprop="postalCode">
#            78748
#           </span>
#          </h2>
#          <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#           <span aria-hidden="true">
#            <i class="ra ra-close-thin">
#            </i>
#           </span>
#          </button>
#         </div>
#        </div>
#        <div class="modal-body fs-map-mobile-body">
#         <div class="ldp-map-container street-fix fullscreen-map" id="photoGalleryLDPMapWrapper">
#          <div id="photoGalleryLDPMobileMap">
#          </div>
#         </div>
#        </div>
#        <div class="modal-footer fs-map-mobile-footer link-secondary" id="fsgalleryMobileMapFooter">
#         <div class="fs-map-btn-wrapper">
#          <div class="hide" id="fsMapView">
#           <a class="btn-circle btn-circle-lg" data-omtag="ldp:slideshow:map" href="#" id="photoGalleryMapBtnMobile">
#            <i class="ra ra-map-marker">
#            </i>
#           </a>
#           <div>
#            <span>
#             Map View
#            </span>
#           </div>
#          </div>
#          <div id="fsStreetView">
#           <a class="btn-circle btn-circle-lg" data-omtag="ldp:slideshow:street" href="#" id="photoGalleryStreetBtnMobile">
#            <i class="ra ra-street-view">
#            </i>
#           </a>
#           <div>
#            <span>
#             Street View
#            </span>
#           </div>
#          </div>
#         </div>
#         <div class="fs-map-btn-wrapper">
#          <a class="btn-circle btn-circle-lg" data-omtag="ldp:map:get-directions" href="https://www.google.com/maps/dir//11400+Midbury+Ct,+Austin,+TX,+78748" id="galleryMapDirectionsBtnMobile" target="_blank">
#           <i class="ra ra-directions">
#           </i>
#          </a>
#          <div>
#           <span>
#            Directions
#           </span>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <script>
#      window.ab_testing = window.ab_testing || [];
#   window.ab_testing.push('ads-482_control');
#     </script>
#     <div class="alert alert-dark alert-dismissible alert-notify alert-fixed-bottom-right hide" id="thank-you-lead-submit" role="alert">
#      <button aria-label="Close" class="close" type="button">
#       <span aria-hidden="true">
#        ×
#       </span>
#      </button>
#      <span class="font-size-small">
#       Thank you! Your message was sent to local real estate professionals. Check your email for details.
#      </span>
#     </div>
#     <!-- Modal -->
#     <div class="alert alert-dark alert-dismissible alert-notify alert-fixed-bottom-right hide" id="thank-you-moving-quote" role="alert">
#      <button aria-label="Close" class="close" type="button">
#       <span aria-hidden="true">
#        ×
#       </span>
#      </button>
#      <span>
#       Thanks! Your message is on its way. A moving professional will contact you soon.
#      </span>
#     </div>
#    </meta>
#   </div>
#   <script>
#    if (window.preloadAds !== undefined) {
#           preloadAds();
#         }
#   </script>
#   <div class="global-nav-footer" id="footer">
#    <div class="footer-wrapper-social">
#     <div class="container">
#      <div class="footer-links-social">
#       <ul class="global-nav-list-justified" id="footer-links-social">
#        <li>
#         <a data-omtag="footer:social:tw" href="https://twitter.com/REALTORdotcom" title="Follow us on Twitter">
#          <i>
#          </i>
#         </a>
#        </li>
#        <li>
#         <a data-omtag="footer:social:fb" href="https://www.facebook.com/realtor.com" title="Like us on Facebook">
#          <i>
#          </i>
#         </a>
#        </li>
#        <li>
#         <a data-omtag="footer:social:pt" href="https://www.pinterest.com/realtordotcom/" title="Find us on Pinterest">
#          <i>
#          </i>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="footer-links-network">
#       <a data-omtag="footer:partners:houseLogic" href="https://www.houselogic.com/?nicmp=hlim%26nichn=footerlink%26niseg=rc" id="footer-link-houselogic" title="Houselogic">
#        <i>
#        </i>
#       </a>
#       <a data-omtag="footer:partners:realtorUniv" href="https://realtoru.edu/about/" id="footer-link-realtoru" title="Realtor University">
#        <i>
#        </i>
#       </a>
#      </div>
#     </div>
#    </div>
#    <input id="channel_flag" name="channel_flag" type="hidden" value="true">
#     <div class="footer-wrapper-links-main">
#      <div class="container">
#       <ul class="global-nav-list-horizontal" id="footer-links-primary">
#        <li>
#         <a data-omtag="footer:corp:about" href="https://www.realtor.com/about/" title="About realtor.com">
#          About Us
#         </a>
#        </li>
#        <li>
#         <a data-omtag="footer:corp:careers" href="https://www.realtor.com/careers/" title="Careers at realtor.com">
#          Careers
#         </a>
#        </li>
#        <li>
#         <a data-omtag="footer:corp:feedback" href="#" id="global-nav-feedback" title="Your feedback">
#          Feedback
#         </a>
#        </li>
#        <li>
#         <a data-omtag="footer:corp:mediaRoom" href="https://news.move.com/" title="Media Room">
#          Media Room
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="footer-wrapper-links-secondary">
#      <div class="container">
#       <ul class="global-nav-list-horizontal" id="footer-links-secondary">
#        <li>
#         <a data-omtag="footer:corp:ad-choices" href="https://www.realtor.com/privacy-policy/" title="Ad Choices">
#          Ad Choices
#         </a>
#        </li>
#        <li>
#         <a data-omtag="footer:corp:advertise" href="https://marketing2.realtor.com/exhibit/" title="Advertise with us">
#          Advertise with us
#         </a>
#        </li>
#        <li>
#         <a data-omtag="footer:corp:agentSupport" href="https://support.realtor.com/s/#iid=rdc_hdr_realtors_support" title="Agent support">
#          Agent support
#         </a>
#        </li>
#        <li class="hide" id="products-footer">
#         <a data-original-title="" data-placement="top" data-popover-content="#footer-popover-products" href="javascript:void(0)" id="toggle-products" rel="popover" title="Products">
#          Products
#         </a>
#         <div class="global-nav-hide footer-popover-content" id="footer-popover-products">
#         </div>
#        </li>
#        <li class="hide" id="news-corp-footer">
#         <a data-original-title="" data-placement="top" data-popover-content="#footer-popover-newscorp" href="javascript:void(0)" id="toggle-newscorp" rel="popover" title="News Corp">
#          News Corp
#         </a>
#         <div class="global-nav-hide footer-popover-content" id="footer-popover-newscorp">
#         </div>
#        </li>
#        <li>
#         <a data-omtag="footer:corp:privacy" href="https://www.realtor.com/privacy-policy/" title="Privacy policy">
#          Privacy
#         </a>
#         /
#         <a data-omtag="footer:corp:terms" href="https://www.realtor.com/terms-of-service" title="Terms of use">
#          Terms
#         </a>
#        </li>
#        <li>
#         <a data-omtag="footer:corp:sitemap" href="https://www.realtor.com/sitemap" title="Realtor.com site map">
#          Sitemap
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="footer-wrapper-copyright">
#      <div class="container">
#       <p id="footer-copyright">
#        ©1995-2019
#        <a data-omtag="footer:corp:nar" href="https://www.nar.realtor" title="National Association of REALTORS website">
#         National Association of REALTORS
#         <sup>
#          ®
#         </sup>
#        </a>
#        and
#        <a href="https://www.move.com/" title="Move, Inc. website">
#         Move, Inc.
#        </a>
#        All rights reserved.
#        <br/>
#        realtor.com
#        <sup>
#         ®
#        </sup>
#        is the official site of the National Association of REALTORS
#        <sup>
#         ®
#        </sup>
#        and is operated by Move, Inc., a subsidiary of News Corp.
#       </p>
#      </div>
#     </div>
#    </input>
#   </div>
#   <div id="modal-container">
#   </div>
#   <script type="text/javascript">
#    window.Krux=window.Krux||((Krux=function(){Krux.q.push(arguments);}).q=[]);
#   </script>
#   <script defer="" src="https://c.amazon-adsystem.com/aax2/apstag.js">
#   </script>
#   <script defer="" src="https://cdn.krxd.net/controltag?confid=J7KSr-4q">
#   </script>
#   <script defer="" src="https://us.tags.newscgp.com/prod/prebid/realtor/pb.js">
#   </script>
#   <script src="https://static.rdc-next-basecamp.rdc.moveaws.com/assets/packs/application_critical-1bbf1501fd9d56e50a94.js">
#   </script>
#   <script src="https://static.rdc-next-basecamp.rdc.moveaws.com/assets/packs/ldp_critical-d55f996857a19dfc1f9b.js">
#   </script>
#   <script type="text/javascript">
#    //<![CDATA[
#       $.extend(
#         MOVE_DATA.propertyDetails,
#         {"canonical":"https://www.realtor.com/realestateandhomes-detail/11400-Midbury-Ct_Austin_TX_78748_M78631-75807","display_lot_size_display?":true,"display_listing_agent?":true,"display_rcm_checkbox?":true,"display_request_more_details_form?":true,"lead_form_title":"More about this property","beds":4,"baths":"2+","has_baths_half_or_full?":true,"sqft_display":"2,834","address_display":"11400 Midbury Ct","flags":{"is_showcase":false,"is_cobroke":true,"is_address_suppressed":false,"has_private_showing":false,"is_coshow_product":false,"is_pre_approved":true,"is_office_standard":false,"has_realtor_logo":true,"is_suppress_map_pin":false,"is_suppress_map":false,"is_price_reduced":false,"is_new_listing":true,"is_pending":false,"is_contingent":false,"is_short_sale":null,"is_foreclosure":false,"is_mortgage_feature":false,"should_suppress_ads":false,"show_porch_link":false,"has_tour":false,"is_costar":false,"is_new_construction":false,"should_suppress_listing_agent":false,"is_advantage_brand":false,"is_advantage_pro":false,"is_advantage":false,"is_essentials":false,"is_basic_opt_in":true,"is_basic_opt_out":false,"is_basic":true,"is_fios_supported":null,"is_fios_gige":null,"is_fios_sfu":null,"is_aptlist":false,"is_tcpa_message_enabled":false,"is_swapped":false,"is_seller_promoted":false},"full_address_display":"11400 Midbury Ct, Austin, TX 78748","lead_button_text":"Contact Agent","lead_service":"LCS","lead_capture_product":"co_broke","photos":[{"url":"https://ap.rdcpix.com/236830441/a915943ce8fc1e414062e79dabd54b47l-m0xd-w640_h480_q80.jpg","description":"","type":null,"tags":[{"label":"exterior","probability":0.587,"href":"https://ap.rdcpix.com/236830441/a915943ce8fc1e414062e79dabd54b47l-m0xd-w300_h300_q80.jpg"},{"label":"street_view","probability":0.411},{"label":"bedroom","probability":0.001}]}],"price":308900,"property_status":"for_sale","listing_provider":{"agent_name":"Steven Dumas","agent_photo":null,"agent_profile_link":"/realestateagents/Steven-Dumas_Austin_TX_3318020_945269412","agent_billing_id":null,"broker_name":"Elite Texas Properties","broker_billing_id":null,"broker_location":"HOUSTON, TX","broker_number":"(832) 428-8961","broker_link":"http://www.austinhomesearch.com/","buyer_agent_name":null,"buyer_broker_name":null,"buyer_broker_number":null,"mls_id":"1392127","mls_name":"Austin","mls_copy_right":"© 2019, Austin Board of REALTORS®, Inc., All Rights Reserved.","mls_abbreviation":"AUTX","office_contact":"(832) 428-8961","buyer_agent_adv_id":null,"buyer_agent_profile_link":null,"buyer_office_adv_id":null,"buyer_office_link":null,"agent_adv_id":3318020,"agent_office_link":"WWW.ELITETEXASPROPERTIES.COM","agent_office_adv_id":2976616},"lot_size":6360,"lot_size_display":"6,360","display_save_listing?":true,"property_type":"for_sale","display_city_state_zip":"Austin, TX 78748","features_list":["Bedrooms","Bathrooms","Appliances","Kitchen and Dining","Other Rooms","Heating and Cooling","Interior Features","Exterior and Lot Features","Land Info","Garage and Parking","Homeowners Association","School Information","Other Property Info","Building and Construction","Utilities","Legal and finance"],"sqft":2834,"year_built":2003,"save_aware":true,"baths_full":"2","baths_half":"1","meta_tags":{"propertyStatusSub":null},"is_mobile":false,"display_seller_broker?":false,"display_tfn_on_lead_form?":false,"display_rcm_checkbox":true,"haven_cta_enabled":false,"haven_myhome_tracking_enabled":false,"is_user_claimed_home":null,"haven_property_cta":"/own","address_unavailable":false,"homes_around_title":"Homes around Midbury Ct","leadfm_ab_test":"control","img_ctr_swap":"C1","vitality_count":"C1","schedule_tour_enabled":true,"display_building_units?":false}
#       );
#     //]]>
#   </script>
#   <script>
#    //<![CDATA[
# window.Gnav={};Gnav.site_id="rdcV8";Gnav.menu_id="";Gnav.BootstrapPresentFlag="";Gnav.basecamp="true";
# //]]>
#   </script>
#   <script src="https://static.gnav-prod.rdc.moveaws.com/assets/application_with_raas-d929266296806909521e902f711c00165e4c613136954632e706a4563296f643.js">
#   </script>
#   <script async="async" src="https://d33nq717p9jm1d.cloudfront.net/dtm_bundle/161/faebb50624175676cb77dee13f41dc903c81f27e/satelliteLib-55d21e8caa3d58b6207a9d1707e7dce9f3f19a44.js">
#   </script>
#   <script type="text/javascript">
#    window.kxdl = {"unitname":"RDC2/LDP/SALE","address":"11400_MIDBURY_CT","cityldp":"AUSTIN","st":"TX","citystldp":"AUSTIN_TX","zipldp":"78748","countyldp":"48453","mlid":"2692213958","mprid":"7863175807","builder_id":"","builder_sub_id":"","bedldp":"4","bathldp":"2.5","openldp":"TRUE","rdpr":"FALSE","t":"BL","add":"092719","lstat":"NEW","lotldp":".5","sqft":"2834","sqldp":"2500_2999","agehom":"5","broker_advertiser_id":"","office_advertiser_id":"2976616","agent_advertiser_id":"3318020","mls":"1392127","bid":"","offbid":"","bkr":"OTHER","listingprice":"308900","pldp":"250K_500K,85K,250K,300K","ptldp":"1","pfldp":"CA,FAMRM,SEWER","garageldp":"2","opensrch":"FALSE","pfsrch":"","zipsrch":"","citysrch":"","tsrch":"","bedsrch":"","bathsrch":"","sqsrch":"","lotsrch":"","min":"","max":"","ptsrch":"0","postmove":"","premove":"","jy":"D05B18BC264443A3B47644EE41E97974","vst":"D05B18BC-2644-43A3-B476-44EE41E97974","news_id":"","split":"26","split_tcv":"101","platform":"WEB_DESK","basecamp":"TRUE","disable_vu":"FALSE","se":"","searchword":""};
#   window.addEventListener("load", function() {
#     MOVE.Medias.init(true);
#   });
#   </script>
#   <script type="text/javascript">
#    if (window.performance && typeof(newrelic) !== 'undefined') {
#     newrelic.setCustomAttribute('render_stream', 'true');
#     newrelic.setCustomAttribute('cluster', 'v');
#     newrelic.setCustomAttribute('split', 'n');
#     newrelic.setCustomAttribute('split_tcv', '101');
#     newrelic.setCustomAttribute('variation', 'SRPBCRR:v1');
#     newrelic.setCustomAttribute('feps_version', 'v2');
#     newrelic.setCustomAttribute('feps_status', 'true');
#   }
#   </script>
#   <script type="text/javascript">
#    if (typeof jQuery !== 'undefined' && window) {
#       jQuery(window).on('load', function() {
#         var challengeScript = document.createElement('script');
#         challengeScript.setAttribute('type', 'text/javascript');
#         challengeScript.setAttribute('src', '/rdc_user_check.js');
#         document.body.appendChild(challengeScript);
#       });
#     }
#   </script>
#   <script>
#    window.googleOneTapEnabled = true
#       window.googleSignUpEnabled = true
#   </script>
#  </body>
# </html>

# %%
crawl_page_estate(test_soup, 'estate')
# Out:
# Status
#
#             Active
#
#
# Price/Sq Ft
# $109
#
# On realtor.com®
# 1 day
#
# Type
# Single Family Home
#
# Built
# 2003
#
# Style
#
#             1st Floor Entry
# {'Branding Agent Name': 'Steven Dumas',
#  'Branding Office Name': 'Elite Texas Properties',
#  'Branding Builder Name': None,
#  'Beds': 4,
#  'Baths': 2.5,
#  'Sqft': 2834.0,
#  'Lotsize': 6360.0,
#  'Price': 308900,
#  'Category': 'Real Estate > Homes For Sale',
#  'Address': '11400 Midbury Ct,Austin,TX78748',
#  'Latitude': 30.156801,
#  'Longitude': -97.842946,
#  'Status': 'Active',
#  'Price/SqFt': 109,
#  'Hours Listed For': 24,
#  'Type': 'Single Family Home',
#  'Built': 2003,
#  'Style': '1st Floor Entry',
#  'Bedrooms': 4.0,
#  'Total Bathrooms': ' 2 / 1',
#  'Full Bathrooms': 2.0,
#  '1/2 Bathrooms': 1.0,
#  'Dining Room Description': ' Breakfast Area, Dining L, Formal Dining Room, Liv/Din Combo',
#  'Fencing': ' Fence',
#  'Lot Size Square Feet': 6360.0,
#  'View': ' City',
#  'Laundry Facilities': ' Dryer Connection - Electric, Kitchen, Main Level, Separate, Utility/Laundry Room',
#  'Cooling Features': ' Central Air',
#  'Fireplace Features': ' Family Room, Formal Living',
#  'Heating Features': ' Electric',
#  'Lot Description': ' Drought Tolerant Landscaping',
#  'Lot Size Acres': 0.146,
#  'Number of Garage Spaces': 2.0,
#  'Garage Features': 2.0,
#  'Parking Features': ' Garage',
#  'Parking Total': 4.0,
#  'Association': ' Yes',
#  'Association Fee': 300.0,
#  'Association Fee Frequency': ' Annually',
#  'Association Fee Includes': ' Common Area Maintenance',
#  'Calculated Total Monthly Association Fees': 25.0,
#  'Association Name': ' Hill Crest HOA',
#  'Elementary School': ' Menchaca',
#  'High School': ' Akins',
#  'Middle School': ' Bailey',
#  'School District': ' Austin ISD',
#  'Annual Tax Amount': 7084.0,
#  'Source Listing Status': ' Active',
#  'County': ' Travis',
#  'Directions': ' Head south on Manchaca then right on Ravenscroft then left on Kingsgate then right on Riker Ridge then right on Midbury',
#  'Tax Year': 2019.0,
#  'Source Property Type': ' House',
#  'Area': ' SWE',
#
# [44 rows x 94 columns]

# %%
def crawl_realtor_com():
    base_search_url = "https://www.realtor.com/realestateandhomes-search"
    base_detail_url = "https://www.realtor.com/realestateandhomes-detail"
    austin_houses_url = base_search_url + "/Austin_TX"
    
    property_types = ["estate", "plan", "land"]

    soup = create_soup(austin_houses_url)
    
    if soup is None:
        return None
    
    for i in range(1, int(find_page_count(soup))+1):
        house_data = []
        page_url = austin_houses_url + "/pg-" + str(i)
        house_urls_uniq = crawl_index_page(create_soup(page_url))
        for house in house_urls_uniq:
            house_url = base_detail_url + house
            house_soup = create_soup(house_url)
            
            print("Crawling page: ", house_url)
            for property_type in property_types:
                try:
                    estate_data = crawl_page_estate(house_soup, property_type)
                    estate_data["Property Type"] = property_type
                    break
                except AttributeError:
                    pass
                
            if estate_data is None:
                print(house_soup.prettify())
                return None
            
            estate_data["url"] = house_url
            house_data.append(estate_data)
            estate_data = None
            
        house_data = pd.DataFrame.from_dict(house_data, orient='columns')
        house_data.set_index("Address", inplace=True)
        
        if i == 1:
            set_cols = True
        else:
            set_cols = False
        
        house_data.to_csv("HouseData.csv", mode='a', header=set_cols)
            
        print("Finished page: ", i)
        break
            
    return house_data

# %%
p = {"a": 4}
t = {"g": 5}
y = []
y.append(p)
y.append(t)
pd.DataFrame.from_dict(y, orient='columns')
# Out:
#      a    g
# 0  4.0  NaN
# 1  NaN  5.0

# %%
def create_soup(url, parser='html.parser'):
    
    #This header is used to trick the webpage into believing the request is sent from a browser
    headers = ({'User-Agent':
            'Mozilla/5.0 (Macintosh; Intel Mac OS X x.y; rv:42.0) AppleWebKit/537.36 (KHTML, like Gecko) Safari/537.36'}
              )
    req = requests.get(url, headers=headers)
    
    return BeautifulSoup(req.text, parser)

# %%
def crawl_index_page(souped_page):
    """
    Params:
        souped_page: the soup object containing html of webpage
    """
    
    urls = []
    
    for listing in souped_page.find_all(class_="component_property-card"):
        data_wrap = listing.find(class_="data-wrap")
        if data_wrap != None:
            url = data_wrap.get("data-url")
            urls.append(url)
        
    return urls

# %%
def crawl_page_estate(souped_page, page_type):
    """
    Params:
        souped_page: the soup object containing html of webpage
    """
    
    estate_data = {}
    
    #Get and store agent information
    estate_data.update(branding_agent_info(souped_page, page_type))
    
    #Get and store main metadata
    estate_data.update(main_metadata(souped_page, page_type))
    
    #Find and store listing section details. Should contain the following:
        #Status, year built, property type, price per sq ft, time listed for, garage
    estate_data.update(main_details(souped_page, page_type))
    
    #Find and store property description if available
    estate_data.update(property_description(souped_page, page_type))

    #Find and store each property detail
    estate_data.update(property_details(souped_page, page_type))
    
    return estate_data

# %%
def branding_agent_info(souped_page, page_type):
    
    estate_data = {}
    
    #Get and store agent information
    if page_type == 'plan':
        branding_builder_name = remove_junk_chars(souped_page.find(attrs={"data-label": "branding-builder-name"}).text)
        estate_data["Branding Builder Name"] = branding_builder_name
        estate_data["Branding Agent Name"] = None
        estate_data["Branding Office Name"] = None
    else:
        branding_agent_name = souped_page.find(attrs={"data-label": "branding-agent-name"}).text
        estate_data["Branding Agent Name"] = branding_agent_name
        branding_office_name = souped_page.find(attrs={"data-label": "branding-office-name"}).text
        estate_data["Branding Office Name"] = branding_office_name
        estate_data["Branding Builder Name"] = None
    
    return estate_data

# %%
def main_metadata(souped_page, page_type):
    
    estate_data = {}
    
    #Get main metadata
    main_info = souped_page.find(class_="header-main-info")
    price = remove_junk_chars(main_info.find(attrs={"itemprop": "price"}).text, "currency")
    category = main_info.find(attrs={"itemprop": "category"})["content"]
    address = remove_junk_chars(main_info.find(class_="ldp-header-address").text, "general")
    latitude = main_info.find(attrs={"itemprop": "latitude"})["content"]
    longitude = main_info.find(attrs={"itemprop": "longitude"})["content"]
    if page_type != 'land':
        beds = main_info.find(attrs={"data-label": "property-meta-beds"}).find(class_="data-value").text
        baths = remove_junk_chars(main_info.find(attrs={"data-label": "property-meta-bath"}).find(class_="data-value").text, 'number')
        sqft = remove_junk_chars(main_info.find(attrs={"data-label": "property-meta-sqft"}).find(class_="data-value").text, "number")
        estate_data["Beds"] = int(beds)
        estate_data["Baths"] = float(baths)
        estate_data["Sqft"] = float(sqft)
    if page_type != 'plan':
        try:
            lotsize = remove_junk_chars(main_info.find(attrs={"data-label": "property-meta-lotsize"}).find(class_="data-value").text, "number")
            estate_data["Lotsize"] = float(lotsize)
        except AttributeError:
            estate_data["Lotsize"] = None
    
    #Store main metadata
    try:
        estate_data["Price"] = int(price)
        estate_data["Category"] = category
        estate_data["Address"] = address
        estate_data["Latitude"] = float(latitude)
        estate_data["Longitude"] = float(longitude)
    except:
        pass
    
    return estate_data

# %%
def main_details(souped_page, page_type):
    
    estate_data = {}
    
    #Find and store listing section details. Should contain the following:
        #Status, year built, property type, price per sq ft, time listed for, garage
    listing_detail_section = souped_page.find(class_="listing-section-details")
    listing_details = listing_detail_section.find_all(class_="ldp-key-fact-item")
    for detail in enumerate(listing_details):
        index = detail[0]
        detail_segments = list(detail[1].children)
        detail_segments = [segment for segment in detail_segments if segment != '\n']
        detail_reformatted = reformat_detail(detail_segments[1].text, remove_junk_chars(detail_segments[2].text, "general"))
        
        estate_data[detail_reformatted[0]] = detail_reformatted[1]
        
    return estate_data

# %%
def property_description(souped_page, page_type):
    
    estate_data = {}
    
    #Find and store property description if available
    property_description_begin = souped_page.find(class_="details-load-more")
    description = property_description_begin.find(id="ldp-detail-romance")
    if description is not None:
        estate_data["description"] = description.text
        
    return estate_data

# %%
def property_details(souped_page, page_type):
    
    estate_data = {}
    
    listing_detail_section = souped_page.find(class_="listing-section-details")
    
    #Find and clean property details section
    root_removable = "feature-fullscreen-gallery-"
    removable = ["exterior_and_lot_features", "kitchen_and_dining", "bathrooms", "bedrooms"]
    for toremove in removable:
        try:
            listing_detail_section.find(id=root_removable + toremove).decompose()
        except:
            pass
    
    #Variables to store property features
    property_details = clean_text(listing_detail_section.text)
    property_features = []
    
    #Read section and store text that follows 'Property Features', as preceding info is not useful
    start_parsing = False
    for line in iter(property_details.splitlines()):
        if line == "Property Features":
            start_parsing = True
            continue
        if start_parsing:
            property_features.append(line)
        else:
            pass
        
    #Read and store each property detail
    for line in property_features:
        breakdown = line.split(":")
        if len(breakdown) == 1:
            continue
        try:
            breakdown[1] = float(remove_junk_chars(breakdown[1], "currency"))
        except:
            pass
        estate_data[breakdown[0]] = breakdown[1]
        
    return estate_data

# %%
def clean_text(text):
    """
    Purpose:
        Removes empty lines from input string
    Params:
        text: string to edit
    """
    
    new_text = ""
    for line in iter(text.splitlines()):
        if not line:
            pass
        else:
            new_text = new_text + line + "\n"
    return new_text

# %%
def reformat_detail(detail_identifier, detail_data):
    """
    Purpose:
        Parses a detail type passed in to modify it's format correspondingly
        Ex. Pass in $5,000 and return 5000
    Params:
        detail: the detail data to modify
        detail_index: index of detail serving as the identifier
        detail_type: type of detail (key or value)
    """
    
    if detail_identifier == "Property Type":
        return detail.replace(" ", "")
    elif detail_identifier == "Price/Sq Ft":
        return [detail_identifier, int(remove_junk_chars(detail_data, 'currency'))]
    elif detail_identifier == "On realtor.com®":
        return ["Hours Listed For", convert_english_time_to_hours(detail_data)]
    elif detail_identifier == "Built":
        return [detail_identifier, int(detail_data)]
        
    return [detail_identifier, detail_data]

# %%
def convert_english_time_to_hours(time):
    """
    Purpose:
        Convert a relative time expressed in English to hours integer
    Params:
        time: english time string to convert
    """
    
    segments = time.split()
    switcher = {
        "hour": 1,
        "day": 24,
        "week": 24*7,
        "month": 24*7*28,
        "year": 24*7*28*365
    }
    for measure in switcher:
        if measure in segments[1]:
            return int(segments[0]) * switcher[measure]

# %%
def remove_junk_chars(data, data_type="general"):
    """
    Purpose:
        Remove junk characters from a passed in string
    Params:
        data: string to remove characters from
        data_type: the type of data passed in which will determine which characters are 'junk'
    """
    
    switcher = {
        "currency": [" ", ",", "\n", "$"],
        "general": ["  ", "\n"],
        "number": [",", "+"]
    }
    
    replace_chars = switcher[data_type]
    for char in replace_chars:
        data = data.replace(char, "")
    return data

# %%
def find_page_count(soup):
    counter = 0
    pagination = soup.find(class_="pagination")
    for child in pagination.children:
        if counter == 9:
            return int(child.text.replace("\n", ""))
        counter+=1

# %% [markdown]
# ### Outdated Functions

# %%
def crawl_basic_page(souped_page):
    """
    Params:
        souped_page: the soup object containing html of webpage
    """
    
    i = 0;
    for listing in souped_page.find_all(class_="component_property-card"):
        data_wrap = listing.find(class_="data-wrap")
        if data_wrap != None:
            address = data_wrap.get("data-plan_name")
            status = data_wrap.get("data-status")
            url = data_wrap.get("data-url")
            price = data_wrap.get("data-price")
            product_name = data_wrap.get("data-product_name")
            baths_full = data_wrap.get("data-baths_full")
            baths_half = data_wrap.get("data-baths-half")
            lot_size = data_wrap.get("data-lot_size")
            beds = listing.find(attrs={"data-label": "property-meta-beds"}).text[0]
            prop_size = listing.find(attrs={"data-label": "property-meta-sqft"}).text
            prop_size = int(prop_size[0:-5].replace(",", ""))
            #beds = listing.find(attrs={"data-label": "property-meta-lotsize"}).text[0]
            garage = listing.find(attrs={"data-label": "property-meta-garage"}).text[0]
            print(url)
        i+=1
        if i == 10:
           break
